# %%
import csv
import pandas as pd
import numpy as np

# %%
incident_data = pd.read_csv('Metro-Incident-Data.csv')
incident_data_two = pd.read_csv('Metro-Incident-Data-2.csv')

# %%
incident_data
# Out:
#                            Date        Time  \
# 0      2012-12-31T05:00:00.000Z   5:00 a.m.
# 1      2012-12-31T05:00:00.000Z  10:30 a.m.
# 2      2012-12-31T05:00:00.000Z   4:11 p.m.
# 3      2012-12-31T05:00:00.000Z   4:50 p.m.
# 4      2012-12-31T05:00:00.000Z   5:55 p.m.
# 5      2012-12-31T05:00:00.000Z   7:38 p.m.
# 6      2012-12-31T05:00:00.000Z   9:33 p.m.
# 7      2012-12-31T05:00:00.000Z  11:09 p.m.
# 8      2012-12-31T05:00:00.000Z  11:32 p.m.
# 9      2012-12-30T05:00:00.000Z  10:45 a.m.
# 10     2012-12-30T05:00:00.000Z  10:49 a.m.
# 11     2012-12-30T05:00:00.000Z  12:24 p.m.
# 12     2012-12-30T05:00:00.000Z  12:34 p.m.
# 13     2012-12-30T05:00:00.000Z   5:19 p.m.
# 14     2012-12-30T05:00:00.000Z   6:39 p.m.
# 15     2012-12-30T05:00:00.000Z   7:40 p.m.
# 16     2012-12-30T05:00:00.000Z   9:40 p.m.
# 17     2012-12-30T05:00:00.000Z   9:43 p.m.
# 18     2012-12-29T05:00:00.000Z   2:28 a.m.
# 19     2012-12-29T05:00:00.000Z  10:21 a.m.
# ...

# %%
incident_data_two
# Out:
#                                time              direction   color  \
# 0       November 16, 2016 5:13 a.m.  Franconia-Springfield    Blue
# 1       November 16, 2016 6:04 a.m.      Largo Town Center    Blue
# 2       November 16, 2016 6:46 a.m.              Greenbelt   Green
# 3       November 16, 2016 6:46 a.m.          Branch Avenue   Green
# 4       November 16, 2016 7:00 a.m.     Wiehle-Reston East  Silver
# 5       November 16, 2016 7:18 a.m.     Wiehle-Reston East  Silver
# 6       November 16, 2016 8:16 a.m.                 Vienna  Orange
# 7       November 16, 2016 8:45 a.m.                    NaN     NaN
# 8       November 16, 2016 8:46 a.m.            Shady Grove     Red
# 9       November 16, 2016 8:50 a.m.         NoMa-Gallaudet     Red
# 10      November 16, 2016 8:58 a.m.            Shady Grove     Red
# 11      November 16, 2016 8:59 a.m.         NoMa-Gallaudet     Red
# 12      November 16, 2016 9:03 a.m.         NoMa-Gallaudet     Red
# ...
